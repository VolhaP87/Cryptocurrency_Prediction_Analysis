# %%
import pandas as pd

# %%
ethereum_df = pd.read_csv('ETH-USD.csv')
ethereum_df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-11-09  308.644989  329.451996  307.056000  320.884003  320.884003
# 1  2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 2  2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 3  2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 4  2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
#
#        Volume
# 0   893249984
# 1   885985984
# 2   842300992
# 3  1613479936
# 4  1041889984

# %%
ethereum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1749 entries, 0 to 1748
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1749 non-null   object
#  1   Open       1749 non-null   float64
#  2   High       1749 non-null   float64
#  3   Low        1749 non-null   float64
#  4   Close      1749 non-null   float64
#  5   Adj Close  1749 non-null   float64
#  6   Volume     1749 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 95.8+ KB

# %%
ethereum_df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
ethereum_df['Date'] = pd.to_datetime(ethereum_df['Date'], infer_datetime_format=True)
ethereum_df.set_index('Date', inplace=True)
ethereum_df.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-08-19  1847.095337  1847.095337  1611.338867  1612.987305  1612.987305
# 2022-08-20  1612.650635  1652.218750  1534.298828  1577.003784  1577.003784
# 2022-08-21  1576.543579  1640.936523  1569.046509  1619.318970  1619.318970
# 2022-08-22  1619.166870  1622.778809  1535.014771  1622.505859  1622.505859
# 2022-08-23  1621.652344  1662.942871  1569.428589  1646.860229  1646.860229
#
#                  Volume
# Date
# 2022-08-19  25906358731
# 2022-08-20  18334580263
# 2022-08-21  15849221752
# 2022-08-22  18557078599
# 2022-08-23  18563018752

# %%
ethereum_df = ethereum_df.ffill()

# %%
ethereum_df['Average Price'] = (ethereum_df['High'] + ethereum_df['Low'])/2
ethereum_df.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-08-19  1847.095337  1847.095337  1611.338867  1612.987305  1612.987305
# 2022-08-20  1612.650635  1652.218750  1534.298828  1577.003784  1577.003784
# 2022-08-21  1576.543579  1640.936523  1569.046509  1619.318970  1619.318970
# 2022-08-22  1619.166870  1622.778809  1535.014771  1622.505859  1622.505859
# 2022-08-23  1621.652344  1662.942871  1569.428589  1646.860229  1646.860229
#
#                  Volume  Average Price
# Date
# 2022-08-19  25906358731    1729.217102
# 2022-08-20  18334580263    1593.258789
# 2022-08-21  15849221752    1604.991516
# 2022-08-22  18557078599    1578.896790
# 2022-08-23  18563018752    1616.185730

# %%
ethereum_df = ethereum_df.loc[:, ['Average Price']]
ethereum_df.tail()
# Out:
#             Average Price
# Date
# 2022-08-19    1729.217102
# 2022-08-20    1593.258789
# 2022-08-21    1604.991516
# 2022-08-22    1578.896790
# 2022-08-23    1616.185730

# %%
bitcoin_df = pd.read_csv('BTC-USD (1).csv')
bitcoin_df = bitcoin_df[bitcoin_df['Date'] >= '2017-11-09']
bitcoin_df.head()
# Out:
#            Date         Open         High          Low        Close  \
# 312  2017-11-09  7446.830078  7446.830078  7101.520020  7143.580078
# 313  2017-11-10  7173.729980  7312.000000  6436.870117  6618.140137
# 314  2017-11-11  6618.609863  6873.149902  6204.220215  6357.600098
# 315  2017-11-12  6295.450195  6625.049805  5519.009766  5950.069824
# 316  2017-11-13  5938.250000  6811.189941  5844.290039  6559.490234
#
#        Adj Close      Volume
# 312  7143.580078  3226249984
# 313  6618.140137  5208249856
# 314  6357.600098  4908680192
# 315  5950.069824  8957349888
# 316  6559.490234  6263249920

# %%
bitcoin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1749 entries, 312 to 2060
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1749 non-null   object
#  1   Open       1749 non-null   float64
#  2   High       1749 non-null   float64
#  3   Low        1749 non-null   float64
#  4   Close      1749 non-null   float64
#  5   Adj Close  1749 non-null   float64
#  6   Volume     1749 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 109.3+ KB

# %%
bitcoin_df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
bitcoin_df['Date'] = pd.to_datetime(bitcoin_df['Date'], infer_datetime_format=True)
bitcoin_df.set_index('Date', inplace=True)
bitcoin_df.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2022-08-19  23213.312500  23213.312500  20868.847656  20877.552734
# 2022-08-20  20872.841797  21350.806641  20856.730469  21166.060547
# 2022-08-21  21160.392578  21668.845703  21103.197266  21534.121094
# 2022-08-22  21531.462891  21531.462891  20939.183594  21398.908203
# 2022-08-23  21398.632813  21641.283203  20955.138672  21498.322266
#
#                Adj Close       Volume
# Date
# 2022-08-19  20877.552734  40509610260
# 2022-08-20  21166.060547  27595671000
# 2022-08-21  21534.121094  23102307723
# 2022-08-22  21398.908203  31666498758
# 2022-08-23  21498.322266  32123942912

# %%
bitcoin_df = bitcoin_df.ffill()
bitcoin_df['Average Price'] = (bitcoin_df['High'] + bitcoin_df['Low'])/2
bitcoin_df = bitcoin_df.loc[:, ['Average Price']]
bitcoin_df.tail()
# Out:
#             Average Price
# Date
# 2022-08-19   22041.080078
# 2022-08-20   21103.768555
# 2022-08-21   21386.021485
# 2022-08-22   21235.323242
# 2022-08-23   21298.210938

# %%
tether_df = pd.read_csv('USDT-USD.csv')
tether_df.head()
# Out:
#          Date     Open     High       Low    Close  Adj Close      Volume
# 0  2017-11-09  1.01087  1.01327  0.996515  1.00818    1.00818   358188000
# 1  2017-11-10  1.00650  1.02423  0.995486  1.00601    1.00601   756446016
# 2  2017-11-11  1.00598  1.02621  0.995799  1.00899    1.00899   746227968
# 3  2017-11-12  1.00602  1.10591  0.967601  1.01247    1.01247  1466060032
# 4  2017-11-13  1.00448  1.02929  0.975103  1.00935    1.00935   767884032

# %%
tether_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1749 entries, 0 to 1748
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1749 non-null   object
#  1   Open       1749 non-null   float64
#  2   High       1749 non-null   float64
#  3   Low        1749 non-null   float64
#  4   Close      1749 non-null   float64
#  5   Adj Close  1749 non-null   float64
#  6   Volume     1749 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 95.8+ KB

# %%
tether_df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
tether_df['Date'] = pd.to_datetime(tether_df['Date'], infer_datetime_format=True)
tether_df.set_index('Date', inplace=True)
tether_df = tether_df.ffill()
tether_df['Average Price'] = (tether_df['High'] + tether_df['Low'])/2
tether_df = tether_df.loc[:, ['Average Price']]
tether_df.tail()
# Out:
#             Average Price
# Date
# 2022-08-19       1.000061
# 2022-08-20       1.000053
# 2022-08-21       1.000052
# 2022-08-22       1.000002
# 2022-08-23       0.999976

# %%
joined_df = bitcoin_df.join(ethereum_df, how='outer', rsuffix=' Ethereum').join(tether_df, how='outer', rsuffix=' Tether')
joined_df
# Out:
#             Average Price  Average Price Ethereum  Average Price Tether
# Date
# 2017-11-09    7274.175049              318.253998              1.004892
# 2017-11-10    6874.435059              309.629989              1.009858
# 2017-11-11    6538.685058              308.822494              1.011005
# 2017-11-12    6072.029785              308.833008              1.036755
# 2017-11-13    6327.739990              317.720001              1.002197
# ...                   ...                     ...                   ...
# 2022-08-19   22041.080078             1729.217102              1.000061
# 2022-08-20   21103.768555             1593.258789              1.000053
# 2022-08-21   21386.021485             1604.991516              1.000052
# 2022-08-22   21235.323242             1578.896790              1.000002
# 2022-08-23   21298.210938             1616.185730              0.999976
#
# [1749 rows x 3 columns]

# %%
df_monthly = df.resample('MS')
month_mean = df_monthly.mean()
month_mean.head()
# Out:
#             Average Price Bitcoin  Average Price Ethereum  \
# Date
# 2017-11-01            8001.447044              378.197771
# 2017-12-01           15123.610525              631.707857
# 2018-01-01           13043.688886             1094.367160
# 2018-02-01            9431.706918              871.787036
# 2018-03-01            9058.444171              630.191097
#
#             Average Price Tether
# Date
# 2017-11-01              1.005164
# 2017-12-01              1.016251
# 2018-01-01              1.007154
# 2018-02-01              0.999852
# 2018-03-01              1.000401

# %%
joined_df.isnull().sum()
# Out:
# Average Price             0
# Average Price Ethereum    0
# Average Price Tether      0
# dtype: int64

# %%
df = joined_df.rename(columns={"Average Price" : "Average Price Bitcoin"})
df
# Out:
#             Average Price Bitcoin  Average Price Ethereum  \
# Date
# 2017-11-09            7274.175049              318.253998
# 2017-11-10            6874.435059              309.629989
# 2017-11-11            6538.685058              308.822494
# 2017-11-12            6072.029785              308.833008
# 2017-11-13            6327.739990              317.720001
# ...                           ...                     ...
# 2022-08-19           22041.080078             1729.217102
# 2022-08-20           21103.768555             1593.258789
# 2022-08-21           21386.021485             1604.991516
# 2022-08-22           21235.323242             1578.896790
# 2022-08-23           21298.210938             1616.185730
#
#             Average Price Tether
# Date
# 2017-11-09              1.004892
# 2017-11-10              1.009858
# 2017-11-11              1.011005
# 2017-11-12              1.036755
# 2017-11-13              1.002197
# ...                          ...
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2017-11-09', '2017-11-10', '2017-11-11', '2017-11-12',
#                '2017-11-13', '2017-11-14', '2017-11-15', '2017-11-16',
#                '2017-11-17', '2017-11-18',
#                ...
#                '2022-08-14', '2022-08-15', '2022-08-16', '2022-08-17',
#                '2022-08-18', '2022-08-19', '2022-08-20', '2022-08-21',
#                '2022-08-22', '2022-08-23'],
#               dtype='datetime64[ns]', name='Date', length=1749, freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

ax = df.plot(figsize=(16,6))
ax.set_ylabel('Average Price (United States dollar)', fontsize=16)
ax.set_xlabel('Date', fontsize=16)
ax.set_title('Average Price of Top Cryptocurriences from November, 2017 to August, 2022', fontsize=20)
plt.show;

# %%
df.hist(figsize=(10,6));

# %%
fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(18,6))
df['Average Price Bitcoin'].plot(kind='kde', ax=axes[0])
axes[0].set_title('Bitcoin Density Plot')
df['Average Price Ethereum'].plot(kind='kde', ax=axes[1])
axes[1].set_title('Ethereum Density Plot')
df['Average Price Tether'].plot(kind='kde', ax=axes[2])
axes[2].set_title('Tether Density Plot');

# %%
df['Average Price Bitcoin'].plot(figsize=(16,6), linewidth=2, fontsize=14)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Average Bitcoin Price', fontsize=20);

# %%
def stationarity_check(DF):
    
    # Import adfuller
    from statsmodels.tsa.stattools import adfuller
    
    # Calculate rolling statistics
    roll_mean = DF.rolling(window=8, center=False).mean()
    roll_std = DF.rolling(window=8, center=False).std()
    
    # Perform the Dickey Fuller test
    dftest = adfuller(DF) 
    
    # Plot rolling statistics:
    fig = plt.figure(figsize=(16,6))
    orig = plt.plot(DF, color='blue',label='Original')
    mean = plt.plot(roll_mean, color='red', label='Rolling Mean')
    std = plt.plot(roll_std, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    # Print Dickey-Fuller test results
    print('Results of Dickey-Fuller Test: \n')

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', 
                                             '#Lags Used', 'Number of Observations Used'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
    return None

# %%
stationarity_check(df['Average Price Bitcoin'])
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                   -1.401705
# p-value                           0.581458
# #Lags Used                        9.000000
# Number of Observations Used    1739.000000
# Critical Value (1%)              -3.434116
# Critical Value (5%)              -2.863203
# Critical Value (10%)             -2.567656
# dtype: float64

# %% [markdown]
# Bitcoin is not stationary.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(np.log(df['Average Price Bitcoin']))

# Gather the trend, seasonality, and residuals 
trend_bitcoin = decomposition.trend
seasonal_bitcoin = decomposition.seasonal
residual_bitcoin = decomposition.resid

# Plot gathered statistics
plt.figure(figsize=(16,8))
plt.subplot(411)
plt.plot(np.log(df['Average Price Bitcoin']), label='Original', color='blue')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend_bitcoin, label='Trend', color='blue')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal_bitcoin,label='Seasonality', color='blue')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual_bitcoin, label='Residuals', color='blue')
plt.legend(loc='best')
plt.tight_layout()

# %%
bitcoin_log_decompose = residual_bitcoin
bitcoin_log_decompose.dropna(inplace=True)

stationarity_check(bitcoin_log_decompose)
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                -1.395393e+01
# p-value                        4.648095e-26
# #Lags Used                     2.300000e+01
# Number of Observations Used    1.719000e+03
# Critical Value (1%)           -3.434160e+00
# Critical Value (5%)           -2.863223e+00
# Critical Value (10%)          -2.567666e+00
# dtype: float64

# %% [markdown]
# The bitcoin time series looks stationary now and is ready for modelling

# %%
df['Average Price Ethereum'].plot(figsize=(16,6), linewidth=2, fontsize=14)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Average Ethereum Price', fontsize=20);

# %%
stationarity_check(df['Average Price Ethereum'])
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                   -1.394762
# p-value                           0.584785
# #Lags Used                        8.000000
# Number of Observations Used    1740.000000
# Critical Value (1%)              -3.434114
# Critical Value (5%)              -2.863202
# Critical Value (10%)             -2.567655
# dtype: float64

# %% [markdown]
#  not stationary

# %%
decomposition = seasonal_decompose(np.log(df['Average Price Ethereum']))

# Gather the trend, seasonality, and residuals 
trend_ethereum = decomposition.trend
seasonal_ethereum = decomposition.seasonal
residual_ethereum = decomposition.resid

# Plot gathered statistics
plt.figure(figsize=(16,8))
plt.subplot(411)
plt.plot(np.log(df['Average Price Ethereum']), label='Original', color='blue')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend_ethereum, label='Trend', color='blue')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal_ethereum,label='Seasonality', color='blue')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual_ethereum, label='Residuals', color='blue')
plt.legend(loc='best')
plt.tight_layout()

# %%
ethereum_log_decompose = residual_ethereum
ethereum_log_decompose.dropna(inplace=True)

stationarity_check(ethereum_log_decompose)
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                -1.405347e+01
# p-value                        3.147351e-26
# #Lags Used                     2.200000e+01
# Number of Observations Used    1.720000e+03
# Critical Value (1%)           -3.434158e+00
# Critical Value (5%)           -2.863222e+00
# Critical Value (10%)          -2.567665e+00
# dtype: float64

# %%
df['Average Price Tether'].plot(figsize=(16,6), linewidth=2, fontsize=14)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Average Tether Price', fontsize=20);

# %%
stationarity_check(df['Average Price Tether'])
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                   -4.822168
# p-value                           0.000049
# #Lags Used                       20.000000
# Number of Observations Used    1728.000000
# Critical Value (1%)              -3.434140
# Critical Value (5%)              -2.863214
# Critical Value (10%)             -2.567661
# dtype: float64

# %% [markdown]
# Tether is stationary (test statistic is less than critical value)

# %%
fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(18,6))
residual_bitcoin.plot(kind='hist', ax=axes[0])
axes[0].set_title('Bitcoin Price Distribution')
residual_ethereum.plot(kind='hist', ax=axes[1])
axes[1].set_title('Ethereum Price Distribution')
df['Average Price Tether'].plot(kind='hist', ax=axes[2])
axes[2].set_title('Tether Price Distribution');

# %%
fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(18,6))
residual_bitcoin.plot(kind='kde', ax=axes[0])
axes[0].set_title('Bitcoin Density Plot')
residual_ethereum.plot(kind='kde', ax=axes[1])
axes[1].set_title('Ethereum Density Plot')
df['Average Price Tether'].plot(kind='kde', ax=axes[2])
axes[2].set_title('Tether Density Plot');

# %%
import numpy as np
print('Mean Bitcoin :', np.mean(residual_bitcoin))
print('Mean Ethereum :', np.mean(residual_ethereum))
print('Mean Tether:', np.mean(df['Average Price Tether']))
# Out:
# Mean Bitcoin : -2.9146198095269777e-05
# Mean Ethereum : 3.10773085352867e-05
# Mean Tether: 1.0021096455117209

# %%
print('Std Bitcoin :', np.std(residual_bitcoin))
print('Std Ethereum :', np.std(residual_ethereum))
print('Std Tether:', np.std(df['Average Price Tether']))
# Out:
# Std Bitcoin : 0.02644635882085321
# Std Ethereum : 0.03277254576044179
# Std Tether: 0.00638371933670947

# %%
jan_bitcoin = residual_bitcoin['2019-01']
march_bitcoin = residual_bitcoin['2021-03']
jan_ethereum = residual_ethereum['2019-01']
march_ethereum = residual_ethereum['2021-03']
jan_tether = df[df['Average Price Tether']=='2019-01']
march_tether = df[df['Average Price Tether']=='2021-03']
print('January 2019: ', '\n')
print("Mean Bitcoin: ")
print(np.mean(jan_bitcoin))
print("Mean Ethereum: ")
print(np.mean(jan_ethereum))
print("Mean Tether: ")
print(np.mean(jan_tether))
print("Std Bitcoin: ")
print(np.std(jan_bitcoin))
print("Std Ethereum: ")
print(np.std(jan_ethereum))
print("Std Tether: ")
print(np.std(jan_tether), '\n')
print("------")
print("Mean Bitcoin: ")
print(np.mean(march_bitcoin))
print("Mean Ethereum: ")
print(np.mean(march_ethereum))
print("Mean Tether: ")
print(np.mean(march_tether))
print("Std Bitcoin: ")
print(np.std(march_bitcoin))
print("Std Ethereum: ")
print(np.std(march_ethereum))
print("Std Tether: ")
print(np.std(march_tether))
# Out:
# January 2019:
#
# Mean Bitcoin:
# -0.00018441410733275497
# Mean Ethereum:
# 0.0010590625626167361
# Mean Tether:
# Average Price Bitcoin    NaN
# Average Price Ethereum   NaN
# Average Price Tether     NaN
# dtype: float64
# Std Bitcoin:
# 0.014780967662780342
# Std Ethereum:
# 0.02417426133916351
# Std Tether:
# Average Price Bitcoin    NaN
# Average Price Ethereum   NaN
# Average Price Tether     NaN
# dtype: float64
#
# ------
# Mean Bitcoin:
# 0.001028278406868916
# Mean Ethereum:
# -0.000980625997897214
# Mean Tether:
# Average Price Bitcoin    NaN
# Average Price Ethereum   NaN
# Average Price Tether     NaN
# dtype: float64
# Std Bitcoin:
# 0.022798793671700564
# Std Ethereum:
# 0.02356838529616571
# Std Tether:
# Average Price Bitcoin    NaN
# Average Price Ethereum   NaN
# Average Price Tether     NaN
# dtype: float64

# %% [markdown]
# Nothing is white noise process since mean and std are not constant over time

# %%
df.corr()
# Out:
#                         Average Price Bitcoin  Average Price Ethereum  \
# Average Price Bitcoin                1.000000                0.926742
# Average Price Ethereum               0.926742                1.000000
# Average Price Tether                -0.176043               -0.175821
#
#                         Average Price Tether
# Average Price Bitcoin              -0.176043
# Average Price Ethereum             -0.175821
# Average Price Tether                1.000000

# %% [markdown]
# The average price for ethereum and bitcoin are highly correlated

# %%
df_diff = df.diff(periods=1)
df_diff.plot(figsize=(16,6), subplots=True, legend=True);

# %%
df_diff.corr()
# Out:
#                         Average Price Bitcoin  Average Price Ethereum  \
# Average Price Bitcoin                1.000000                0.754439
# Average Price Ethereum               0.754439                1.000000
# Average Price Tether                 0.033982                0.024105
#
#                         Average Price Tether
# Average Price Bitcoin               0.033982
# Average Price Ethereum              0.024105
# Average Price Tether                1.000000

# %% [markdown]
# Differencing the series led to the decrease in correlation. Ethereum and bitcoin are moving in more or less the same direction. Seasonality is not present.

# %% [markdown]
# Let's look at the 'lag-1 autocorrelation' for the bitcoin

# %%
bitcoin = df[['Average Price Bitcoin']]
bitcoin_shift_1 = bitcoin.shift(periods=1)
lag_1 = pd.concat([bitcoin_shift_1, bitcoin], axis=1)
lag_1.plot(figsize=(18,6));.fi

# %%
lag_1.corr()
# Out:
#                        Average Price Bitcoin  Average Price Bitcoin
# Average Price Bitcoin               1.000000               0.998839
# Average Price Bitcoin               0.998839               1.000000

# %%
bitcoin_shift_50 = bitcoin.shift(periods=50)
lag_50 = pd.concat([bitcoin_shift_50, bitcoin], axis=1)
lag_50.plot(figsize=(18,6));

# %%
lag_50.corr()
# Out:
#                        Average Price Bitcoin  Average Price Bitcoin
# Average Price Bitcoin               1.000000               0.893303
# Average Price Bitcoin               0.893303               1.000000

# %% [markdown]
# The autocorrelation is still high with a lag of 50. This is because it is a random walk series, which are highly recursive and each value depends heavily on the previous one

# %%
plt.figure(figsize=(12,5))
pd.plotting.autocorrelation_plot(bitcoin.dropna());

# %% [markdown]
# The series is heavily autocorrelated at first, and then there is a decay. This is a typical result for a series that is random walk.
# Let's look at the partial sutocorrelation function plot.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 14,5
plot_pacf(bitcoin.dropna(), lags=50, method='ywm');

# %%
bitcoin_diff = bitcoin.diff(periods=1)
plt.figure(figsize=(18,5))
pd.plotting.autocorrelation_plot(bitcoin_diff.dropna());

# %%
rcParams['figure.figsize'] = 14,5
plot_pacf(bitcoin_diff.dropna(), lags=50);
